# %%
import random

attempted = 0
guessed_word = []
attempt_remaining = 5
wrong_guess = []
game_on = True
wrong = 0

name = input("Enter your name to start the game!!!!!!!!!! ")
print("Hello " + name + ", Welcome to the game! ")
word_list = ["hello","apple","banana","guava","litchi","pineapple","grapes"]
word = random.choice(word_list)
print(word)
word_len = len(word)
print("Length of the word is = {} " .format(word_len)) 
board_word = "_" * word_len
print(board_word)


def play_game():
    
    global board_word
    global game_on

    while game_on:
        
        if "_" in board_word:
            word_generate()
                   
        else:
            print("your answer is completer ")
            game_on = False
    
    print("Your word is ", word)
            
def word_generate():
    
    global attempted
    global attempt_remaining
    global board_word
    global guessed_word
    global wrong

    print("board has place ................... ")
    letter = input("Enter your guess to put in the word : ")
    
    if letter in guessed_word:
        print("Already guessed......... Try again")
    
    elif letter in word:
        print("Good..... ")
        attempted += 1
        guessed_word.append(letter)
        attempt_remaining -= 1
        print("Attempted ", attempted)
        print("Guessed ", guessed_word)
        print("Remaining Attempt ", attempt_remaining)

        for index, char in enumerate(word):
            if word[index] == letter:
                loc_letter = index
                print("Index of {} in word " .format(letter), loc_letter)
                board_word = board_word[:loc_letter] + letter + board_word[loc_letter+1:]
                print(board_word)
                        
    else:
        print("your guessed letter is wrong and not fit in word")
        attempted += 1
        guessed_word.append(letter)
        attempt_remaining -= 1
        wrong_guess.append(letter)
        wrong += 1
        print("Attempted ", attempted)
        print("Guessed ", guessed_word)
        print("Remaining Attempt ", attempt_remaining)
        print("Wrong guessed", wrong_guess)
        if wrong == 1:
            print("   _____ \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "__|__\n")
        elif wrong == 2:
            print("   _____ \n"
                  "  |     | \n"
                  "  |     |\n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "__|__\n")
        elif wrong == 3:
            print("   _____ \n"
                 "  |     | \n"
                 "  |     |\n"
                 "  |     | \n"
                 "  |      \n"
                 "  |      \n"
                 "  |      \n"
                 "__|__\n")
        elif wrong == 4:
            print("   _____ \n"
                  "  |     | \n"
                  "  |     |\n"
                  "  |     | \n"
                  "  |     O \n"
                  "  |      \n"
                  "  |      \n"
                  "__|__\n")
        elif wrong == 5:
            print("   _____ \n"
                  "  |     | \n"
                  "  |     |\n"
                  "  |     | \n"
                  "  |     O \n"
                  "  |    /|\ \n"
                  "  |    / \ \n"
                  "__|__\n")

play_game()
# Out:
# Enter your name to start the game!!!!!!!!!! aka
# Hello aka, Welcome to the game!
# litchi
# Length of the word is = 6
# ______
# board has place ...................
# Enter your guess to put in the word : a
# your guessed letter is wrong and not fit in word
# Attempted  1
# Guessed  ['a']
# Remaining Attempt  4
# Wrong guessed ['a']
#    _____
#   |
#   |
#   |
#   |
#   |
#   |
# __|__
#
# board has place ...................
# Enter your guess to put in the word : l
# Good.....
# Attempted  2
# Guessed  ['a', 'l']
# Remaining Attempt  3
# Index of l in word  0
# l_____
# board has place ...................
# Enter your guess to put in the word : i
# Good.....
# Attempted  3
# Guessed  ['a', 'l', 'i']
# Remaining Attempt  2
# Index of i in word  1
# li____
# Index of i in word  5
# li___i
# board has place ...................
# Enter your guess to put in the word : i
# Already guessed......... Try again
# board has place ...................
# Enter your guess to put in the word : c
# Good.....
# Attempted  4
# Guessed  ['a', 'l', 'i', 'c']
# Remaining Attempt  1
# Index of c in word  3
# li_c_i
# board has place ...................
# Enter your guess to put in the word : h
# Good.....
# Attempted  5
# Guessed  ['a', 'l', 'i', 'c', 'h']
# Remaining Attempt  0
# Index of h in word  4
# li_chi
# board has place ...................
# Enter your guess to put in the word : i
# Already guessed......... Try again
# board has place ...................
# Enter your guess to put in the word : y
# your guessed letter is wrong and not fit in word
# Attempted  6
# Guessed  ['a', 'l', 'i', 'c', 'h', 'y']
# Remaining Attempt  -1
# Wrong guessed ['a', 'y']
#    _____
#   |     |
#   |     |
#   |
#   |
#   |
#   |
# __|__
#
# board has place ...................
# Enter your guess to put in the word : k
# your guessed letter is wrong and not fit in word
# Attempted  7
# Guessed  ['a', 'l', 'i', 'c', 'h', 'y', 'k']
# Remaining Attempt  -2
# Wrong guessed ['a', 'y', 'k']
#    _____
#   |     |
#   |     |
#   |     |
#   |
#   |
#   |
# __|__
#
# board has place ...................
# Enter your guess to put in the word : l
# Already guessed......... Try again
# board has place ...................
# Enter your guess to put in the word : p
# your guessed letter is wrong and not fit in word
# Attempted  8
# Guessed  ['a', 'l', 'i', 'c', 'h', 'y', 'k', 'p']
# Remaining Attempt  -3
# Wrong guessed ['a', 'y', 'k', 'p']
#    _____
#   |     |
#   |     |
#   |     |
#   |     O
#   |
#   |
# __|__
#
# board has place ...................
# Enter your guess to put in the word : q
# your guessed letter is wrong and not fit in word
# Attempted  9
# Guessed  ['a', 'l', 'i', 'c', 'h', 'y', 'k', 'p', 'q']
# Remaining Attempt  -4
# Wrong guessed ['a', 'y', 'k', 'p', 'q']
#    _____
#   |     |
#   |     |
#   |     |
#   |     O
#   |    /|\
#   |    / \
# __|__
#
# board has place ...................
# Enter your guess to put in the word : x
# your guessed letter is wrong and not fit in word
# Attempted  10
# Guessed  ['a', 'l', 'i', 'c', 'h', 'y', 'k', 'p', 'q', 'x']
# Remaining Attempt  -5
# Wrong guessed ['a', 'y', 'k', 'p', 'q', 'x']
# board has place ...................
